# %%
# %sql
CREATE TABLE workspace.input_data.drug_file_tracker (
    id BIGINT GENERATED ALWAYS AS IDENTITY,
    file_name STRING
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS workspace.input_data.drug_file_chunk (
    chunk_id BIGINT GENERATED ALWAYS AS IDENTITY,
    file_name STRING,
    drug_name STRING,
    chunk_text STRING,
    created_at TIMESTAMP
)

# %%
# %sql
ALTER TABLE workspace.input_data.drug_file_chunk
SET TBLPROPERTIES (
  'delta.enableChangeDataFeed' = 'true'
);
