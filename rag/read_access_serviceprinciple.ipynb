# %%
import requests
import json

# %%
workspace_url = "https://dbc-41fdb423-e2e5.cloud.databricks.com/"
token = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()

url = f"{workspace_url}/api/2.0/secrets/acls/put"

payload = {
    "scope": "project-dev",
    "principal": "44c8f108-bd7c-439b-826d-e499e5fcd6ea",
    "permission": "READ"
}

headers = {
    "Authorization": f"Bearer {token}"
}

response = requests.post(url, headers=headers, json=payload)
print(response.text)
